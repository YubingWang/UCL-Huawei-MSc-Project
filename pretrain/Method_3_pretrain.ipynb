# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install all needed libraries
# !pip install transformers
# !pip install datasets
# !pip install pypinyin
# !pip install pkuseg
# !pip install evaluate
# !pip install difflib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.2-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 14.9 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 78.2 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 84.5 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.9.1 tokenizers-0.12.1 transformers-4.21.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 15.2 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 97.6 MB/s
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 95.3 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.9.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.7.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 79.0 MB/s
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, xxhash, responses, multiprocess, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.4.0 multiprocess-0.70.13 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pypinyin
#   Downloading pypinyin-0.47.1-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 14.6 MB/s
# Installing collected packages: pypinyin
# Successfully installed pypinyin-0.47.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pkuseg
#   Downloading pkuseg-0.0.25-cp37-cp37m-manylinux1_x86_64.whl (50.2 MB)
#      |████████████████████████████████| 50.2 MB 151.9 MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from pkuseg) (0.29.32)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pkuseg) (1.21.6)
# Installing collected packages: pkuseg
# Successfully installed pkuseg-0.0.25
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting evaluate
#   Downloading evaluate-0.2.2-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 5.8 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from evaluate) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from evaluate) (1.3.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (2.23.0)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (2022.7.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.18.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.3.5.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from evaluate) (1.21.6)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from evaluate) (4.64.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from evaluate) (3.0.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.9.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from evaluate) (4.12.0)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (2.4.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.70.13)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets>=2.0.0->evaluate) (3.8.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.7.0->evaluate) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (3.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.1.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->evaluate) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->evaluate) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->evaluate) (1.15.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.2.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement difflib (from versions: none)
# ERROR: No matching distribution found for difflib

# %%
# import libraries for transformers, segmentation, pinyin and etc...
from transformers import BertTokenizer, BartForConditionalGeneration, GPT2LMHeadModel, TextGenerationPipeline
import pkuseg
from pypinyin import Style, lazy_pinyin, pinyin
import string
import numpy as np
import torch
import math
import random
import evaluate 
import os

# %%
# connect to cuda if available
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# set the tokenizer and model using pretrained model from huggingface
tokenizer = BertTokenizer.from_pretrained("fnlp/bart-base-chinese")
model = BartForConditionalGeneration.from_pretrained("fnlp/bart-base-chinese")
seg = pkuseg.pkuseg()
# Out:
# Downloading vocab.txt:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/449 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/1.59k [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'BertTokenizer'.
# Downloading pytorch_model.bin:   0%|          | 0.00/570M [00:00<?, ?B/s]

# %%
# Get the alphabet of capital letters
alphabet = string.ascii_letters[26:]

# The punctuation list
PUNCS = set([",", ".", "?", "!", ":", "，", "。", "？", "！", "："])

# The yunmu dictionary for rhyming: all yunmus in the same number group rhyme.
yunmus= {
            "0":["a", "ia", "ua", "va", "üa"],
            "1":["e", "o", "uo", "ie", "ue", "üe", "ve"],
            "2":["u"],
            "3":["i", "ü", "v"],
            "4":["ai", "uai"],
            "5":["ao", "iao"],
            "6":["ou", "iu", "iou"],
            "7":["an", "ian", "uan", "üan", "van"],
            "8":["en", "in", "un", "ün", "vn"],
            "9":["ang", "iang", "uang"],
            "10":["eng", "ing", "ueng", "ong", "iong"],
            "11":["er"],
            "12":["ei", "ui", "uei", "vei"],
           }

yun2id = {}
for yid, yws in yunmus.items():
    for w in yws:
        yun2id[w] = yid

# %%
# adding special mask tokens for each rhyming group 
num_added_toks = tokenizer.add_tokens(['[RHYME]'])
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(21129, 768)

# %%
# Return the yunmu of the last word in the input text
def yunmu_name(text):
    w = text[-1]
    if w in PUNCS and len(text) > 1:
        w = text[-2]
    yunmu = lazy_pinyin(w, style=Style.FINALS)
    yunmu = yunmu[0]
    return yunmu

# Return the corresponding yunmu_id of the yunmu
def yunmu_id(yunmu):
    if yunmu in yun2id:
        id = yun2id[yunmu]
    else:
        id = '-1'
    return id

# Return the corresponding schema of the sentences
def sents_to_schema(sents):
    m = 0
    all_id = []
    schema = ''
    for sent in sents:
        y_id = int(yunmu_id(yunmu_name(sent)))
        if y_id in all_id:
            schema += schema[all_id.index(y_id)]
        else:
            schema += alphabet[m]
            m += 1
        all_id.append(y_id)
    return schema

# clean the inputs, get rid of the spaces and punctuations and put the text into sentences in a list
def clean_text(text):
    text = text.replace(" ", "")
    for punc in PUNCS:
        text = text.replace(punc, " ")
    sents = text.split()
    return sents

def rhyme_mapping(sents):
    rhys = []
    for sent in sents:
        yunmu = yunmu_name(sent)
        rhys.append(yunmu)
    assert len(rhys) == len(sents)
    rhy_map = {}
    for i, r in enumerate(rhys):
        rid = yunmu_id(r)
        if rid in rhy_map:
            rhy_map[rid] += [i]
        else:
            rhy_map[rid] = [i]
    rhy_list = []
    for rid in rhy_map:
        rhy_list.append(rhy_map[rid])
    return rhy_map, rhy_list

def encode_text(sents, rhy_list):
    new_sents = list(sents)
    for i in rhy_list:
        ori_text = sents[i]
        segmentation = seg.cut(ori_text)
        mask_word = segmentation[-1]
        new_sents[i] = ori_text[:len(ori_text)-len(mask_word)] + '[RHYME]'
    new_text = '，'.join(new_sents)
    return new_text

# %%
# Evaluation model for perplexity
from transformers import BertTokenizer, GPT2LMHeadModel, TextGenerationPipeline
eval_tokenizer = BertTokenizer.from_pretrained("uer/gpt2-chinese-lyric")
eval_model = GPT2LMHeadModel.from_pretrained("uer/gpt2-chinese-lyric")

def eval_ppl(text):
    encodings = eval_tokenizer(text, return_tensors="pt")
    max_length = eval_model.config.n_positions
    length = encodings.input_ids.size(1)

    trg_len = length
    input_ids = encodings.input_ids[:, length - max_length:]
    target_ids = input_ids.clone()
    target_ids[:, :-trg_len] = -100

    with torch.no_grad():
        outputs = eval_model(input_ids, labels=target_ids)
        neg_log_likelihood = outputs[0] * trg_len

    ppl = torch.exp(neg_log_likelihood / length)
    return ppl
# Out:
# Downloading vocab.txt:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/253 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/401M [00:00<?, ?B/s]

# %%
data_path = r'/content/drive/MyDrive/MSc_Project/dataset/train_eval_test'

train_text = []
train_label = []
with open(os.path.join(data_path, 'train_data.txt'), 'r') as td:
    for line in td:
        line = line.rstrip()
        sents = clean_text(line)
        _, rhy_list = rhyme_mapping(sents)
        for i in range(len(rhy_list)):
          train_label.append(line)
          train_text.append(encode_text(sents, rhy_list[i]))

eval_text = []
eval_label = []
with open(os.path.join(data_path, 'eval_data.txt'), 'r') as ed:
    for line in ed:
        line = line.rstrip()
        sents = clean_text(line)
        _, rhy_list = rhyme_mapping(sents)
        for i in range(len(rhy_list)):
          eval_label.append(line)
          eval_text.append(encode_text(sents, rhy_list[i]))

test_text = []
test_label = []
with open(os.path.join(data_path, 'test_data.txt'), 'r') as ttd:
    for line in ttd:
        line = line.rstrip()
        sents = clean_text(line)
        _, rhy_list = rhyme_mapping(sents)
        for i in range(len(rhy_list)):
          test_label.append(line)
          test_text.append(encode_text(sents, rhy_list[i]))


'''
with open('/content/drive/MyDrive/MSc_Project/dataset/lyric.txt', 'r') as fp:
    text = fp.read().split('\n')

for i in range(len(text)):
    text[i] = encode_text(text[i])
'''
# Out:
# "\nwith open('/content/drive/MyDrive/MSc_Project/dataset/lyric.txt', 'r') as fp:\n    text = fp.read().split('\n')\n\nfor i in range(len(text)):\n    text[i] = encode_text(text[i])\n"

# %%
inputs = tokenizer(train_text, return_tensors='pt', max_length=128, truncation=True, padding='max_length')
eval_inputs = tokenizer(eval_text, return_tensors='pt', max_length=128, truncation=True, padding='max_length')
test_inputs = tokenizer(test_text, return_tensors='pt', max_length=128, truncation=True, padding='max_length')

labels = tokenizer(train_label, return_tensors='pt', max_length=128, truncation=True, padding='max_length')
eval_labels = tokenizer(eval_label, return_tensors='pt', max_length=128, truncation=True, padding='max_length')
test_labels = tokenizer(test_label, return_tensors='pt', max_length=128, truncation=True, padding='max_length')

# %%
inputs['labels'] = labels.input_ids.detach().clone()
eval_inputs['labels'] = eval_labels.input_ids.detach().clone()
test_inputs['labels'] = test_labels.input_ids.detach().clone()

#inputs.keys()

# %%
class LyricsDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    def __getitem__(self, idx):
        return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
    def __len__(self):
        return len(self.encodings.input_ids)

# %%
train_dataset = LyricsDataset(inputs)
eval_dataset = LyricsDataset(eval_inputs)
test_dataset = LyricsDataset(test_inputs)

# %%
# move our model to the selected device
model.to(device)
# activate training mode
model.train()
# Out:
# BartForConditionalGeneration(
#   (model): BartModel(
#     (shared): Embedding(21129, 768)
#     (encoder): BartEncoder(
#       (embed_tokens): Embedding(21129, 768)
#       (embed_positions): BartLearnedPositionalEmbedding(514, 768)
#       (layers): ModuleList(
#         (0): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): Embedding(21129, 768)
#       (embed_positions): BartLearnedPositionalEmbedding(514, 768)
#       (layers): ModuleList(
#         (0): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=768, out_features=21129, bias=False)
# )

# %%
from transformers import AdamW
# initialize optimizer
optim = torch.optim.AdamW(model.parameters(), lr=5e-5)

# %%
from datetime import datetime

# datetime object containing current date and time
time_stamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer

#args = TrainingArguments(output_dir="test_trainer", evaluation_strategy="epoch", per_device_train_batch_size=4)

args = Seq2SeqTrainingArguments(
    output_dir = f"/content/drive/MyDrive/MSc_Project/args/Method_3/{time_stamp}",
    do_predict = True,
    #per_device_train_batch_size = 8,
    num_train_epochs = 5,
    evaluation_strategy ='steps',
    eval_steps = 2000,
    save_strategy ='steps',
    save_steps = 2000,
    save_total_limit = 5, # Only last 5 models are saved. Older ones are deleted.
    load_best_model_at_end = True,
    predict_with_generate = True
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    #compute_metrics=accuracy_metric,
)

# %%
train_result = trainer.train()
trainer.save_model()
metrics = train_result.metrics

trainer.log_metrics("train", metrics)
trainer.save_metrics("train", metrics)
trainer.save_state()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 196082
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 122555
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# The following columns in the training set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
#     <div>
#
#       <progress value='122555' max='122555' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [122555/122555 6:45:43, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2000</td>
#       <td>0.150200</td>
#       <td>0.146535</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.138400</td>
#       <td>0.140789</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.141900</td>
#       <td>0.137112</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.138000</td>
#       <td>0.135239</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.134000</td>
#       <td>0.133233</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.133000</td>
#       <td>0.128825</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.122200</td>
#       <td>0.127449</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.119200</td>
#       <td>0.125967</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.118500</td>
#       <td>0.125418</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.117500</td>
#       <td>0.123092</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.114500</td>
#       <td>0.122145</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.115300</td>
#       <td>0.119251</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.100200</td>
#       <td>0.122755</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.095700</td>
#       <td>0.123715</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.093600</td>
#       <td>0.123258</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.094400</td>
#       <td>0.120829</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.093400</td>
#       <td>0.121027</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>0.091800</td>
#       <td>0.120387</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>0.091100</td>
#       <td>0.120129</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>0.088100</td>
#       <td>0.119677</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>0.087800</td>
#       <td>0.120223</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>0.087800</td>
#       <td>0.118936</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>0.086400</td>
#       <td>0.119561</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>0.086100</td>
#       <td>0.118514</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>0.070600</td>
#       <td>0.122781</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>0.074300</td>
#       <td>0.121398</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>0.070300</td>
#       <td>0.120560</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>0.072800</td>
#       <td>0.120022</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>0.070800</td>
#       <td>0.120823</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>0.075500</td>
#       <td>0.121182</td>
#     </tr>
#     <tr>
#       <td>62000</td>
#       <td>0.074100</td>
#       <td>0.118871</td>
#     </tr>
#     <tr>
#       <td>64000</td>
#       <td>0.073000</td>
#       <td>0.121038</td>
#     </tr>
#     <tr>
#       <td>66000</td>
#       <td>0.074500</td>
#       <td>0.119276</td>
#     </tr>
#     <tr>
#       <td>68000</td>
#       <td>0.070300</td>
#       <td>0.118182</td>
#     </tr>
#     <tr>
#       <td>70000</td>
#       <td>0.072300</td>
#       <td>0.118159</td>
#     </tr>
#     <tr>
#       <td>72000</td>
#       <td>0.069500</td>
#       <td>0.118607</td>
#     </tr>
#     <tr>
#       <td>74000</td>
#       <td>0.056300</td>
#       <td>0.122832</td>
#     </tr>
#     <tr>
#       <td>76000</td>
#       <td>0.054700</td>
#       <td>0.123431</td>
#     </tr>
#     <tr>
#       <td>78000</td>
#       <td>0.057800</td>
#       <td>0.123347</td>
#     </tr>
#     <tr>
#       <td>80000</td>
#       <td>0.057200</td>
#       <td>0.122933</td>
#     </tr>
#     <tr>
#       <td>82000</td>
#       <td>0.057300</td>
#       <td>0.123079</td>
#     </tr>
#     <tr>
#       <td>84000</td>
#       <td>0.058800</td>
#       <td>0.123372</td>
#     </tr>
#     <tr>
#       <td>86000</td>
#       <td>0.056500</td>
#       <td>0.121952</td>
#     </tr>
#     <tr>
#       <td>88000</td>
#       <td>0.056500</td>
#       <td>0.122211</td>
#     </tr>
#     <tr>
#       <td>90000</td>
#       <td>0.054800</td>
#       <td>0.121856</td>
#     </tr>
#     <tr>
#       <td>92000</td>
#       <td>0.056200</td>
#       <td>0.122183</td>
#     </tr>
#     <tr>
#       <td>94000</td>
#       <td>0.056400</td>
#       <td>0.121818</td>
#     </tr>
#     <tr>
#       <td>96000</td>
#       <td>0.056800</td>
#       <td>0.121384</td>
#     </tr>
#     <tr>
#       <td>98000</td>
#       <td>0.057100</td>
#       <td>0.120591</td>
#     </tr>
#     <tr>
#       <td>100000</td>
#       <td>0.045900</td>
#       <td>0.125887</td>
#     </tr>
#     <tr>
#       <td>102000</td>
#       <td>0.045700</td>
#       <td>0.125847</td>
#     </tr>
#     <tr>
#       <td>104000</td>
#       <td>0.046200</td>
#       <td>0.126413</td>
#     </tr>
#     <tr>
#       <td>106000</td>
#       <td>0.045900</td>
#       <td>0.125603</td>
#     </tr>
#     <tr>
#       <td>108000</td>
#       <td>0.047200</td>
#       <td>0.125417</td>
#     </tr>
#     <tr>
#       <td>110000</td>
#       <td>0.046000</td>
#       <td>0.125329</td>
#     </tr>
#     <tr>
#       <td>112000</td>
#       <td>0.043800</td>
#       <td>0.125826</td>
#     </tr>
#     <tr>
#       <td>114000</td>
#       <td>0.045700</td>
#       <td>0.125421</td>
#     </tr>
#     <tr>
#       <td>116000</td>
#       <td>0.045400</td>
#       <td>0.125659</td>
#     </tr>
#     <tr>
#       <td>118000</td>
#       <td>0.045700</td>
#       <td>0.125245</td>
#     </tr>
#     <tr>
#       <td>120000</td>
#       <td>0.045900</td>
#       <td>0.125118</td>
#     </tr>
#     <tr>
#       <td>122000</td>
#       <td>0.044700</td>
#       <td>0.125222</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-2000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-2000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-2000/pytorch_model.bin
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-4000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-4000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-4000/pytorch_model.bin
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-6000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-6000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-6000/pytorch_model.bin
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-8000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-8000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-8000/pytorch_model.bin
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-10000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-10000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-10000/pytorch_model.bin
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-12000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-12000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-12000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-2000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-14000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-14000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-14000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-4000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-16000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-16000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-16000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-6000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-18000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-18000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-18000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-8000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-20000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-20000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-20000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-10000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-22000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-22000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-22000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-12000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-24000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-24000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-24000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-14000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-26000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-26000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-26000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-16000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-28000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-28000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-28000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-18000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-30000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-30000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-30000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-20000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-32000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-32000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-32000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-22000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-34000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-34000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-34000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-26000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-36000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-36000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-36000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-28000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-38000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-38000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-38000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-30000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-40000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-40000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-40000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-32000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-42000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-42000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-42000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-34000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-44000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-44000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-44000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-24000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-46000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-46000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-46000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-36000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-48000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-48000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-48000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-38000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-50000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-50000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-50000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-40000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-52000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-52000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-52000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-42000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-54000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-54000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-54000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-44000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-56000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-56000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-56000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-46000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-58000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-58000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-58000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-50000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-60000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-60000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-60000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-52000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-62000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-62000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-62000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-54000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-64000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-64000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-64000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-56000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-66000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-66000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-66000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-58000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-68000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-68000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-68000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-48000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-70000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-70000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-70000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-60000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-72000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-72000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-72000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-62000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-74000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-74000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-74000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-64000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-76000
# ...
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-96000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-88000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-98000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-98000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-98000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-90000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-100000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-100000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-100000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-92000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-102000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-102000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-102000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-94000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-104000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-104000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-104000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-96000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-106000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-106000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-106000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-98000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-108000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-108000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-108000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-100000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-110000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-110000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-110000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-102000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-112000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-112000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-112000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-104000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-114000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-114000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-114000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-106000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-116000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-116000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-116000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-108000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-118000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-118000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-118000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-110000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-120000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-120000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-120000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-112000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-122000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-122000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-122000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-114000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/checkpoint-70000 (score: 0.11815869063138962).
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_3/2022-09-01 12:50:47/pytorch_model.bin
# ***** train metrics *****
#   epoch                    =        5.0
#   total_flos               = 69592115GF
#   train_loss               =     0.0797
#   train_runtime            = 6:45:46.05
#   train_samples_per_second =      40.27
#   train_steps_per_second   =      5.034

# %%
metrics = trainer.evaluate()
try:
    perplexity = math.exp(metrics["eval_loss"])
except OverflowError:
    perplexity = float("inf")
metrics["perplexity"] = perplexity

trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)
# Out:
# ***** Running Evaluation *****
#   Num examples = 49023
#   Batch size = 8
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
#     <div>
#
#       <progress value='6128' max='6128' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6128/6128 02:51]
#     </div>
# ***** eval metrics *****
#   epoch                   =        5.0
#   eval_loss               =     0.1182
#   eval_runtime            = 0:02:51.47
#   eval_samples_per_second =    285.894
#   eval_steps_per_second   =     35.738
#   perplexity              =     1.1254
