# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install all needed libraries
# !pip install transformers
# !pip install datasets
# !pip install pypinyin
# !pip install pkuseg
# !pip install evaluate
# !pip install difflib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.2-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 4.9 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 60.8 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 90.7 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.9.1 tokenizers-0.12.1 transformers-4.21.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 5.0 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 95.0 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.7.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.9.1)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 99.8 MB/s
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 96.6 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, xxhash, responses, multiprocess, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.4.0 multiprocess-0.70.13 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pypinyin
#   Downloading pypinyin-0.47.1-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.0 MB/s
# Installing collected packages: pypinyin
# Successfully installed pypinyin-0.47.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pkuseg
#   Downloading pkuseg-0.0.25-cp37-cp37m-manylinux1_x86_64.whl (50.2 MB)
#      |████████████████████████████████| 50.2 MB 1.1 MB/s
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pkuseg) (1.21.6)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from pkuseg) (0.29.32)
# Installing collected packages: pkuseg
# Successfully installed pkuseg-0.0.25
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting evaluate
#   Downloading evaluate-0.2.2-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 3.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from evaluate) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from evaluate) (1.3.5)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.9.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from evaluate) (3.0.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from evaluate) (4.64.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from evaluate) (21.3)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (2.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from evaluate) (4.12.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.18.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.70.13)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (2022.7.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from evaluate) (0.3.5.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from evaluate) (2.23.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets>=2.0.0->evaluate) (3.8.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.7.0->evaluate) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->evaluate) (2.10)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->evaluate) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->evaluate) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->evaluate) (1.15.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.2.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement difflib (from versions: none)
# ERROR: No matching distribution found for difflib

# %%
# import libraries for transformers, segmentation, pinyin and etc...
from transformers import BertTokenizer, BartForConditionalGeneration, GPT2LMHeadModel, TextGenerationPipeline
import pkuseg
from pypinyin import Style, lazy_pinyin, pinyin
import string
import numpy as np
import torch
import math
import random
import evaluate 
import os

# %%
# connect to cuda if available
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# set the tokenizer and model using pretrained model from huggingface
tokenizer = BertTokenizer.from_pretrained("fnlp/bart-base-chinese")
model = BartForConditionalGeneration.from_pretrained("fnlp/bart-base-chinese")
seg = pkuseg.pkuseg()
# Out:
# Downloading vocab.txt:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/449 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/1.59k [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'BertTokenizer'.
# Downloading pytorch_model.bin:   0%|          | 0.00/570M [00:00<?, ?B/s]

# %%
# Get the alphabet of capital letters
alphabet = string.ascii_letters[26:]

# The punctuation list
PUNCS = set([",", ".", "?", "!", ":", "，", "。", "？", "！", "："])

# The yunmu dictionary for rhyming: all yunmus in the same number group rhyme.
yunmus= {
            "0":["a", "ia", "ua", "va", "üa"],
            "1":["e", "o", "uo", "ie", "ue", "üe", "ve"],
            "2":["u"],
            "3":["i", "ü", "v"],
            "4":["ai", "uai"],
            "5":["ao", "iao"],
            "6":["ou", "iu", "iou"],
            "7":["an", "ian", "uan", "üan", "van"],
            "8":["en", "in", "un", "ün", "vn"],
            "9":["ang", "iang", "uang"],
            "10":["eng", "ing", "ueng", "ong", "iong"],
            "11":["er"],
            "12":["ei", "ui", "uei", "vei"],
           }

yun2id = {}
for yid, yws in yunmus.items():
    for w in yws:
        yun2id[w] = yid

# %%
# adding special mask tokens for each rhyming group 
num_added_toks = tokenizer.add_tokens(['[A]'])
num_added_toks = tokenizer.add_tokens(['[B]'])
num_added_toks = tokenizer.add_tokens(['[C]'])
num_added_toks = tokenizer.add_tokens(['[D]'])
num_added_toks = tokenizer.add_tokens(['[E]'])
num_added_toks = tokenizer.add_tokens(['[F]'])
num_added_toks = tokenizer.add_tokens(['[G]'])
num_added_toks = tokenizer.add_tokens(['[H]'])
num_added_toks = tokenizer.add_tokens(['[I]'])
num_added_toks = tokenizer.add_tokens(['[J]'])
num_added_toks = tokenizer.add_tokens(['[K]'])
num_added_toks = tokenizer.add_tokens(['[L]'])
num_added_toks = tokenizer.add_tokens(['[M]'])
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(21141, 768)

# %%
# Return the yunmu of the last word in the input text
def yunmu_name(text):
    w = text[-1]
    if w in PUNCS and len(text) > 1:
        w = text[-2]
    yunmu = lazy_pinyin(w, style=Style.FINALS)
    yunmu = yunmu[0]
    return yunmu

# Return the corresponding yunmu_id of the yunmu
def yunmu_id(yunmu):
    if yunmu in yun2id:
        id = yun2id[yunmu]
    else:
        id = '-1'
    return id

# Return the corresponding schema of the sentences
def sents_to_schema(sents):
    m = 0
    all_id = []
    schema = ''
    for sent in sents:
        y_id = int(yunmu_id(yunmu_name(sent)))
        if y_id in all_id:
            schema += schema[all_id.index(y_id)]
        else:
            schema += alphabet[m]
            m += 1
        all_id.append(y_id)
    return schema

# clean the inputs, get rid of the spaces and punctuations and put the text into sentences in a list
def clean_text(text):
    text = text.replace(" ", "")
    for punc in PUNCS:
        text = text.replace(punc, " ")
    sents = text.split()
    return sents


def encode_text(text):
    sents = clean_text(text)
    schema = sents_to_schema(sents)
    new_sents = []
    for i in range(len(sents)):
        ori_text = sents[i]
        segmentation = seg.cut(ori_text)
        mask_word = segmentation[-1]
        new_sents.append(ori_text[:len(ori_text)-len(mask_word)] + '[' + schema[i] + ']')
    new_text = '，'.join(new_sents)
    return new_text

# %%
# Evaluation model for perplexity
from transformers import BertTokenizer, GPT2LMHeadModel, TextGenerationPipeline
eval_tokenizer = BertTokenizer.from_pretrained("uer/gpt2-chinese-lyric")
eval_model = GPT2LMHeadModel.from_pretrained("uer/gpt2-chinese-lyric")

def eval_ppl(text):
    encodings = eval_tokenizer(text, return_tensors="pt")
    max_length = eval_model.config.n_positions
    length = encodings.input_ids.size(1)

    trg_len = length
    input_ids = encodings.input_ids[:, length - max_length:]
    target_ids = input_ids.clone()
    target_ids[:, :-trg_len] = -100

    with torch.no_grad():
        outputs = eval_model(input_ids, labels=target_ids)
        neg_log_likelihood = outputs[0] * trg_len

    ppl = torch.exp(neg_log_likelihood / length)
    return ppl
# Out:
# Downloading vocab.txt:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/253 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/577 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/401M [00:00<?, ?B/s]

# %%
data_path = r'/content/drive/MyDrive/MSc_Project/dataset/train_eval_test'

train_text = []
train_label = []
with open(os.path.join(data_path, 'train_data.txt'), 'r') as td:
    for line in td:
        line = line.rstrip()
        train_label.append(line)
        train_text.append(encode_text(line))

eval_text = []
eval_label = []
with open(os.path.join(data_path, 'eval_data.txt'), 'r') as ed:
    for line in ed:
        line = line.rstrip()
        eval_label.append(line)
        eval_text.append(encode_text(line))

test_text = []
test_label = []
with open(os.path.join(data_path, 'test_data.txt'), 'r') as ttd:
    for line in ttd:
        line = line.rstrip()
        test_label.append(line)
        test_text.append(encode_text(line))


'''
with open('/content/drive/MyDrive/MSc_Project/dataset/lyric.txt', 'r') as fp:
    text = fp.read().split('\n')

for i in range(len(text)):
    text[i] = encode_text(text[i])
'''
# Out:
# "\nwith open('/content/drive/MyDrive/MSc_Project/dataset/lyric.txt', 'r') as fp:\n    text = fp.read().split('\n')\n\nfor i in range(len(text)):\n    text[i] = encode_text(text[i])\n"

# %%
inputs = tokenizer(train_text, return_tensors='pt', max_length=128, truncation=True, padding='max_length')
eval_inputs = tokenizer(eval_text, return_tensors='pt', max_length=128, truncation=True, padding='max_length')
test_inputs = tokenizer(test_text, return_tensors='pt', max_length=128, truncation=True, padding='max_length')

labels = tokenizer(train_label, return_tensors='pt', max_length=128, truncation=True, padding='max_length')
eval_labels = tokenizer(eval_label, return_tensors='pt', max_length=128, truncation=True, padding='max_length')
test_labels = tokenizer(test_label, return_tensors='pt', max_length=128, truncation=True, padding='max_length')

# %%
inputs['labels'] = labels.input_ids.detach().clone()
eval_inputs['labels'] = eval_labels.input_ids.detach().clone()
test_inputs['labels'] = test_labels.input_ids.detach().clone()

#inputs.keys()

# %%
class LyricsDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    def __getitem__(self, idx):
        return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
    def __len__(self):
        return len(self.encodings.input_ids)

# %%
train_dataset = LyricsDataset(inputs)
eval_dataset = LyricsDataset(eval_inputs)
test_dataset = LyricsDataset(test_inputs)

# %%
# move our model to the selected device
model.to(device)
# activate training mode
model.train()
# Out:
# BartForConditionalGeneration(
#   (model): BartModel(
#     (shared): Embedding(21141, 768)
#     (encoder): BartEncoder(
#       (embed_tokens): Embedding(21141, 768)
#       (embed_positions): BartLearnedPositionalEmbedding(514, 768)
#       (layers): ModuleList(
#         (0): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): Embedding(21141, 768)
#       (embed_positions): BartLearnedPositionalEmbedding(514, 768)
#       (layers): ModuleList(
#         (0): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=768, out_features=21141, bias=False)
# )

# %%
from transformers import AdamW
# initialize optimizer
optim = torch.optim.AdamW(model.parameters(), lr=5e-5)

# %%
from datetime import datetime

# datetime object containing current date and time
time_stamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer

#args = TrainingArguments(output_dir="test_trainer", evaluation_strategy="epoch", per_device_train_batch_size=4)

args = Seq2SeqTrainingArguments(
    output_dir = f"/content/drive/MyDrive/MSc_Project/args/Method_2/{time_stamp}",
    do_predict = True,
    #per_device_train_batch_size = 8,
    num_train_epochs = 5,
    evaluation_strategy ='steps',
    eval_steps = 300,
    save_strategy ='steps',
    save_steps = 300,
    save_total_limit = 5, # Only last 5 models are saved. Older ones are deleted.
    load_best_model_at_end = True,
    predict_with_generate = True
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    #compute_metrics=accuracy_metric,
)

# %%
train_result = trainer.train()
trainer.save_model()
metrics = train_result.metrics

trainer.log_metrics("train", metrics)
trainer.save_metrics("train", metrics)
trainer.save_state()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 38102
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 23815
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# The following columns in the training set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
#     <div>
#
#       <progress value='20239' max='23815' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20239/23815 2:02:33 < 21:39, 2.75 it/s, Epoch 4.25/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.644915</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.718800</td>
#       <td>0.626337</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.718800</td>
#       <td>0.625390</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.649200</td>
#       <td>0.606662</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.643100</td>
#       <td>0.600586</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.643100</td>
#       <td>0.593948</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.624100</td>
#       <td>0.589224</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.624100</td>
#       <td>0.583807</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.621200</td>
#       <td>0.578082</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.608600</td>
#       <td>0.576460</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.608600</td>
#       <td>0.570010</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.606800</td>
#       <td>0.567519</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.606800</td>
#       <td>0.565042</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.592000</td>
#       <td>0.558403</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.588500</td>
#       <td>0.553405</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.588500</td>
#       <td>0.561379</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.556900</td>
#       <td>0.557916</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.556900</td>
#       <td>0.553559</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.520500</td>
#       <td>0.552683</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.516000</td>
#       <td>0.550132</td>
#     </tr>
#     <tr>
#       <td>6300</td>
#       <td>0.516000</td>
#       <td>0.550342</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.514000</td>
#       <td>0.544656</td>
#     </tr>
#     <tr>
#       <td>6900</td>
#       <td>0.514000</td>
#       <td>0.538273</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.520800</td>
#       <td>0.540761</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.511600</td>
#       <td>0.534725</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.511600</td>
#       <td>0.533296</td>
#     </tr>
#     <tr>
#       <td>8100</td>
#       <td>0.510700</td>
#       <td>0.530777</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.510700</td>
#       <td>0.529271</td>
#     </tr>
#     <tr>
#       <td>8700</td>
#       <td>0.506900</td>
#       <td>0.528095</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.507200</td>
#       <td>0.521958</td>
#     </tr>
#     <tr>
#       <td>9300</td>
#       <td>0.507200</td>
#       <td>0.521059</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>0.505300</td>
#       <td>0.528307</td>
#     </tr>
#     <tr>
#       <td>9900</td>
#       <td>0.505300</td>
#       <td>0.527251</td>
#     </tr>
#     <tr>
#       <td>10200</td>
#       <td>0.444800</td>
#       <td>0.525847</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.439000</td>
#       <td>0.528486</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>0.439000</td>
#       <td>0.527619</td>
#     </tr>
#     <tr>
#       <td>11100</td>
#       <td>0.439300</td>
#       <td>0.524734</td>
#     </tr>
#     <tr>
#       <td>11400</td>
#       <td>0.439300</td>
#       <td>0.522696</td>
#     </tr>
#     <tr>
#       <td>11700</td>
#       <td>0.438000</td>
#       <td>0.522249</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.436400</td>
#       <td>0.518630</td>
#     </tr>
#     <tr>
#       <td>12300</td>
#       <td>0.436400</td>
#       <td>0.513870</td>
#     </tr>
#     <tr>
#       <td>12600</td>
#       <td>0.434200</td>
#       <td>0.514847</td>
#     </tr>
#     <tr>
#       <td>12900</td>
#       <td>0.434200</td>
#       <td>0.513256</td>
#     </tr>
#     <tr>
#       <td>13200</td>
#       <td>0.442400</td>
#       <td>0.509659</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.435800</td>
#       <td>0.504003</td>
#     </tr>
#     <tr>
#       <td>13800</td>
#       <td>0.435800</td>
#       <td>0.504355</td>
#     </tr>
#     <tr>
#       <td>14100</td>
#       <td>0.440700</td>
#       <td>0.505982</td>
#     </tr>
#     <tr>
#       <td>14400</td>
#       <td>0.440700</td>
#       <td>0.513048</td>
#     </tr>
#     <tr>
#       <td>14700</td>
#       <td>0.406800</td>
#       <td>0.515970</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.383600</td>
#       <td>0.514416</td>
#     </tr>
#     <tr>
#       <td>15300</td>
#       <td>0.383600</td>
#       <td>0.514086</td>
#     </tr>
#     <tr>
#       <td>15600</td>
#       <td>0.374800</td>
#       <td>0.510503</td>
#     </tr>
#     <tr>
#       <td>15900</td>
#       <td>0.374800</td>
#       <td>0.509942</td>
#     </tr>
#     <tr>
#       <td>16200</td>
#       <td>0.383500</td>
#       <td>0.514253</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.379000</td>
#       <td>0.504916</td>
#     </tr>
#     <tr>
#       <td>16800</td>
#       <td>0.379000</td>
#       <td>0.508393</td>
#     </tr>
#     <tr>
#       <td>17100</td>
#       <td>0.388800</td>
#       <td>0.506947</td>
#     </tr>
#     <tr>
#       <td>17400</td>
#       <td>0.388800</td>
#       <td>0.501744</td>
#     </tr>
#     <tr>
#       <td>17700</td>
#       <td>0.385200</td>
#       <td>0.504052</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.378700</td>
#       <td>0.500899</td>
#     </tr>
#     <tr>
#       <td>18300</td>
#       <td>0.378700</td>
#       <td>0.499281</td>
#     </tr>
#     <tr>
#       <td>18600</td>
#       <td>0.381800</td>
#       <td>0.499395</td>
#     </tr>
#     <tr>
#       <td>18900</td>
#       <td>0.381800</td>
#       <td>0.498735</td>
#     </tr>
#     <tr>
#       <td>19200</td>
#       <td>0.379900</td>
#       <td>0.508734</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.346000</td>
#       <td>0.514661</td>
#     </tr>
#     <tr>
#       <td>19800</td>
#       <td>0.346000</td>
#       <td>0.507984</td>
#     </tr>
#     <tr>
#       <td>20100</td>
#       <td>0.341300</td>
#       <td>0.512588</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-300
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-300/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-300/pytorch_model.bin
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-600
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-600/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-600/pytorch_model.bin
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-900
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-900/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-900/pytorch_model.bin
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1200
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1200/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1200/pytorch_model.bin
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1500
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1500/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1500/pytorch_model.bin
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1800
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1800/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1800/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-300] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2100
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2100/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2100/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-600] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2400
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2400/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2400/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-900] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2700
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2700/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2700/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1200] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1500] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3300
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3300/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3300/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-1800] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3600
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3600/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3600/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2100] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3900
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3900/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3900/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2400] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4200
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4200/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4200/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-2700] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4500
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4500/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4800
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4800/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4800/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3300] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5100
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5100/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5100/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3600] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5400
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5400/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5400/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-3900] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5700
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5700/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5700/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4200] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4500] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6300
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6300/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6300/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-4800] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6600
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6600/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6600/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5100] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6900
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6900/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6900/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5400] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7200
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7200/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7200/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-5700] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7500
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7500/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7800
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7800/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7800/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6300] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8100
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8100/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8100/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6600] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8400
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8400/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8400/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-6900] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8700
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8700/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8700/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7200] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7500] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9300
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9300/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9300/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-7800] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9600
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9600/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9600/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8100] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9900
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9900/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9900/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8400] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-10200
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-10200/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-10200/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-8700] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-10500
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-10500/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-10500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-10800
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-10800/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-10800/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9600] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-11100
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-11100/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-11100/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-9900] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# ...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16200
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16200/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16200/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-15000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16500
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16500/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-15300] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16800
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16800/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16800/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-15600] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17100
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17100/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17100/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-15900] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17400
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17400/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17400/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-13500] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17700
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17700/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17700/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16200] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18000
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18000/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18000/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16500] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18300
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18300/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18300/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-16800] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18600
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18600/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18600/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17100] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18900
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18900/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18900/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17400] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-19200
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-19200/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-19200/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-17700] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-19500
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-19500/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-19500/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18000] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-19800
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-19800/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-19800/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18300] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# ***** Running Evaluation *****
#   Num examples = 9525
#   Batch size = 8
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: token_type_ids. If token_type_ids are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# Saving model checkpoint to /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-20100
# Configuration saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-20100/config.json
# Model weights saved in /content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-20100/pytorch_model.bin
# Deleting older checkpoint [/content/drive/MyDrive/MSc_Project/args/Method_2/2022-08-31 14:10:24/checkpoint-18600] due to args.save_total_limit
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """

# %%
metrics = trainer.evaluate()
try:
    perplexity = math.exp(metrics["eval_loss"])
except OverflowError:
    perplexity = float("inf")
metrics["perplexity"] = perplexity

trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)

# %%
import difflib
text = '冷咖啡离开了杯垫，我忍住的情绪在很后面，决定一个人走，我没有后路可退'
new_text = encode_text(text)

# %%
new_text
# Out:
# '冷咖啡离开了[MASK]，我忍住的情绪在很[MASK]，决定一个人[MASK]，我没有后路可[MASK][SEP]AABC'

# %%
tokenizer = BertTokenizer.from_pretrained("fnlp/bart-base-chinese")
import os
PATH = r'/content/drive/MyDrive/MSc_Project/args/Method_1/2022-08-30 20:13:01/checkpoint-4500'
#tokenizer = BertTokenizer.from_pretrained(os.path.join(PATH, 'vocab.txt'), local_files_only=True)
model = BartForConditionalGeneration.from_pretrained(os.path.join(PATH, 'pytorch_model.bin'),config=os.path.join(PATH, 'config.json'), local_files_only=True)

batch = tokenizer(new_text, return_tensors="pt")
generated_ids = model.generate(batch["input_ids"], num_return_sequences = 50, max_length = 150, do_sample = True, temperature = 1.0, output_scores = True, return_dict_in_generate=True)
result = tokenizer.batch_decode(generated_ids["sequences"], skip_special_tokens=True)
result = [s.replace(" ", "") for s in result]
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BartTokenizer'.
# The class this function is called from is 'BertTokenizer'.
# ---------------------------------------------------------------------------
# EntryNotFoundError                        Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     630                 use_auth_token=use_auth_token,
# --> 631                 user_agent=user_agent,
#     632             )
#
# /usr/local/lib/python3.7/dist-packages/transformers/utils/hub.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#     291             use_auth_token=use_auth_token,
# --> 292             local_files_only=local_files_only,
#     293         )
#
# /usr/local/lib/python3.7/dist-packages/transformers/utils/hub.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#     556                     raise EntryNotFoundError(
# --> 557                         f"Cannot find the requested file ({fname}) in the cached path and outgoing traffic has been"
#     558                         " disabled. To enable model look-ups and downloads online, set 'local_files_only'"
#
# EntryNotFoundError: Cannot find the requested file (config.json) in the cached path and outgoing traffic has been disabled. To enable model look-ups and downloads online, set 'local_files_only' to False.
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-235f365682f1> in <module>
#       3 PATH = r'/content/drive/MyDrive/MSc_Project/args/Method_1/2022-08-30 20:13:01/checkpoint-4500'
#       4 #tokenizer = BertTokenizer.from_pretrained(os.path.join(PATH, 'vocab.txt'), local_files_only=True)
# ----> 5 model = BartForConditionalGeneration.from_pretrained(os.path.join(PATH, 'pytorch_model.bin'),config=os.path.join(PATH, 'config.json'), local_files_only=True)
#       6
#       7 batch = tokenizer(new_text, return_tensors="pt")
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1851                 _from_auto=from_auto_class,
#    1852                 _from_pipeline=from_pipeline,
# -> 1853                 **kwargs,
#    1854             )
#    1855         else:
#
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     532         assert unused_kwargs == {"foo": False}
#     533         ```"""
# --> 534         config_dict, kwargs = cls.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     535         if "model_type" in config_dict and hasattr(cls, "model_type") and config_dict["model_type"] != cls.model_type:
#     536             logger.warning(
#
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     559         original_kwargs = copy.deepcopy(kwargs)
#     560         # Get config dict associated with the base config file
# --> 561         config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     562
#     563         # That config file may point us toward another config file to use.
#
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     647         except EntryNotFoundError:
#     648             raise EnvironmentError(
# --> 649                 f"{pretrained_model_name_or_path} does not appear to have a file named {configuration_file}."
#     650             )
#     651         except HTTPError as err:
#
# OSError: /content/drive/MyDrive/MSc_Project/args/Method_1/2022-08-30 20:13:01/checkpoint-4500/config.json does not appear to have a file named config.json.

# %%
list_of_rhyme = ['AAAAAAAAAA', 'AABBCCDDEE', 'ABABABABAB', 'ABCDEABCDE', 'ABCDEFGHIJ']

def stat_metric(rhyme_metric):
  avg = sum(rhyme_metric)/len(rhyme_metric)
  maximum = max(rhyme_metric)
  upper = sum(i >= 0.7 for i in rhyme_metric)
  middle = sum(i >= 0.5 for i in rhyme_metric)
  return [avg, maximum, upper, middle]
#round(avg,3)

def rhyme_stat(list_text, schema):
  rhyme_metric = []
  for i in range(len(result)):
    new_schema = sents_to_schema(clean_text(result[i]))
    new_schema = new_schema[:len(schema)]
    temp = difflib.SequenceMatcher(None,schema,new_schema).ratio()
    rhyme_metric.append(temp)
    ppl = eval_ppl(result[i])
  return stat_metric(rhyme_metric).append(ppl)

# %%
#EXAMPLE 1:
EX_1 = []
for schema in list_of_rhyme:
  new_text = new_text.replace(new_text[-10:],schema)
  batch = tokenizer(new_text, return_tensors="pt")
  generated_ids = model.generate(batch["input_ids"], num_return_sequences = 50, max_length = 200, do_sample = True, temperature = 1.0, output_scores = True, return_dict_in_generate=True)
  result = tokenizer.batch_decode(generated_ids["sequences"], skip_special_tokens=True)
  result = [s.replace(" ", "") for s in result]
  EX_1.append(rhyme_stat(result, schema))

# %%
EX_1
# Out:
# [[0.16873684210526307, 0.5263157894736842, 0, 1],
#  [0.5437894736842106, 0.7368421052631579, 1, 45],
#  [0.5209473684210528, 0.631578947368421, 0, 36],
#  [0.5502105263157895, 0.7, 6, 49],
#  [0.42915789473684185, 0.6, 0, 11]]

# %%
#EXAMPLE 2:
EX_2 = []
for schema in list_of_rhyme:
  new_text = new_text.replace(new_text[-10:],schema)
  batch = tokenizer(new_text, return_tensors="pt")
  generated_ids = model.generate(batch["input_ids"], num_return_sequences = 50, max_length = 200, do_sample = True, temperature = 1.0, output_scores = True, return_dict_in_generate=True)
  result = tokenizer.batch_decode(generated_ids["sequences"], skip_special_tokens=True)
  result = [s.replace(" ", "") for s in result]
  EX_2.append(rhyme_stat(result, schema))

# %%
EX_2
# Out:
# [[0.15210526315789463, 0.6, 0, 3],
#  [0.5451578947368423, 0.7, 2, 46],
#  [0.5357894736842108, 0.631578947368421, 0, 38],
#  [0.5456842105263159, 0.7368421052631579, 4, 49],
#  [0.4354736842105261, 0.7, 1, 16]]

# %%
#EXAMPLE 3:
EX_3 = []
for schema in list_of_rhyme:
  new_text = new_text.replace(new_text[-10:],schema)
  batch = tokenizer(new_text, return_tensors="pt")
  generated_ids = model.generate(batch["input_ids"], num_return_sequences = 50, max_length = 200, do_sample = True, temperature = 1.0, output_scores = True, return_dict_in_generate=True)
  result = tokenizer.batch_decode(generated_ids["sequences"], skip_special_tokens=True)
  result = [s.replace(" ", "") for s in result]
  EX_3.append(rhyme_stat(result, schema))

# %%
EX_3
# Out:
# [[0.14599999999999994, 0.631578947368421, 0, 3],
#  [0.5370526315789474, 0.7368421052631579, 4, 43],
#  [0.5431578947368423, 0.7, 1, 40],
#  [0.5506315789473684, 0.7, 7, 47],
#  [0.4272631578947369, 0.6, 0, 11]]

# %%
import numpy as np
   
# data rows of csv file 
rows = [ ['Nikhil', 'COE', '2', '9.0'], 
         ['Sanchit', 'COE', '2', '9.1'], 
         ['Aditya', 'IT', '2', '9.3'], 
         ['Sagar', 'SE', '1', '9.5'], 
         ['Prateek', 'MCE', '3', '7.8'], 
         ['Sahil', 'EP', '2', '9.1']] 
  
# using the savetxt 
# from the numpy module
np.savetxt(os.path.join(PATH, 'simple_test_result.csv'), 
           rows,
           delimiter =", ", 
           fmt ='% s')

# %%
EXAMPLE 1: 0.580421052631579  0.7
EXAMPLE 4: 0.5808658008658013 0.6666666666666666
EXAMPLE 1gai: 0.502 0.7 'AABBCCDDEE'
EXAMPLE 1gai: 0.502 0.6 'ABABABABAB'
EXAMPLE 1gai: 0.412 0.7 'AAAAAAAAAA' 2/17
EXAMPLE 1gai: 0.488 0.7 'AABBCCDDEE' 3/32
EXAMPLE 1gai: 0.507 0.7 'AABBAABBAA' 2/36
EXAMPLE 1gai: 0.461 0.7 'ABCDEFGHIJ' 1/22

# %%
'AABBCCDDEE' 'ABABCDCDEE'

# %%
'''
TEXT 1: 
text = '最美的不是下雨天，是曾与你躲过雨的屋檐，泪流过的脸，是我记忆模糊一片，如果爱的路上没有了你，会不会有爱的晴天，如果没有你，我会在何处安身，哪怕一直走到了最后一个人，如果没有你'
list_of_rhyme = ['AAAAAAAAAA', 'AABBCCDDEE', 'ABABABABAB', 'ABCDEABCDE', 'ABCDEFGHIJ']

EX_1 = [[0.3747368421052632, 0.7, 1, 15],
 [0.5046315789473685, 0.7, 3, 36],
 [0.5144210526315791, 0.6, 0, 39],
 [0.5249473684210527, 0.7, 2, 42],
 [0.45799999999999985, 0.7, 1, 22]]

EX_2 = [[0.40988888888888886, 0.7, 1, 18],
 [0.4885263157894737, 0.7, 1, 37],
 [0.5180000000000001, 0.6, 0, 37],
 [0.522, 0.7, 1, 41],
 [0.4624999999999999, 0.7, 1, 25]]

 EX_3 = [[0.39, 0.7, 1, 14],
 [0.4764210526315791, 0.7, 1, 27],
 [0.5224210526315789, 0.6, 0, 39],
 [0.5199999999999999, 0.7, 4, 38],
 [0.45042105263157883, 0.7, 1, 21]]
'''

# %%
'''
TEXT 2:
text = '冷咖啡离开了杯垫，我忍住的情绪在很后面，决定一个人走，我没有后路可退，只能承受悲哀来陪，我的痛谁会在意，如果相遇是个意外，我愿意放手让你走，我不想让自己在沉醉，在悲伤中无法自拔'

EX_1 = [[0.16873684210526307, 0.5263157894736842, 0, 1],
 [0.5437894736842106, 0.7368421052631579, 1, 45],
 [0.5209473684210528, 0.631578947368421, 0, 36],
 [0.5502105263157895, 0.7, 6, 49],
 [0.42915789473684185, 0.6, 0, 11]]

EX_2 = [[0.15210526315789463, 0.6, 0, 3],
 [0.5451578947368423, 0.7, 2, 46],
 [0.5357894736842108, 0.631578947368421, 0, 38],
 [0.5456842105263159, 0.7368421052631579, 4, 49],
 [0.4354736842105261, 0.7, 1, 16]]

EX_3 = [[0.14599999999999994, 0.631578947368421, 0, 3],
 [0.5370526315789474, 0.7368421052631579, 4, 43],
 [0.5431578947368423, 0.7, 1, 40],
 [0.5506315789473684, 0.7, 7, 47],
 [0.4272631578947369, 0.6, 0, 11]]

'''
